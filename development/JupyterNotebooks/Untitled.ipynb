# %%
# from dloader import genDataLoader
from fastmri.data import tra`nsforms
import sigpy.plot as pl
import torch

# %%
type(torch.tensor([[[1, 2, 3, 4]]]).shape[0:2]) == tuple
# Out:
# False

# %%
basedirs = ['/mnt/dense/vliu/summer_dset/div_coronal_pd']
train_dloader = genDataLoader(
    [f'{basedir}/Test' for basedir in basedirs], # choose randomly
    [4, 4], # downsample
    center_fractions = [0.05, 0.06, 0.07],
    accelerations = [5, 6, 7],
    shuffle = False,
    num_workers = 16
)

# %%
train_loader = train_dloader[0]
train_iter = iter(train_loader)

# %%
for i in range(28):
    kspace, mask, esp, im_fs, contrast = next(train_iter)
    im_fs_np = transforms.tensor_to_complex_np(im_fs.cpu().detach())
    pl.ImagePlot(im_fs_np) # this is true image

# %%
a = ['hi', 'zed', 'apple']

# %%
sorted(a)
# Out:
# ['apple', 'hi', 'zed']

# %%
import numpy as np

# %%
rng = np.random.default_rng(123)
