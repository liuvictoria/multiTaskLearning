# %% [markdown]
# # Making dataloader
#
# Using the information from `1_intro.ipynb` we will make a dataloader which can produce <br>
# (input) one slice of kspace_us, sensitivity, image_us, (label) image_true
#
# Then, kspace_us, sensitivity, image_us >> Deep Learning Network >> loss(estimated image,image_true) >> backpropagate <br>
# The Deep Learning Network can be either `unrolled network` or `U-Net`

# %%
import numpy as np
import sigpy as sp
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (10,10)

import sigpy.plot as pl
import os, h5py, pathlib # pathlib is a good library for reading files in a nested folders

from torch.utils.data import DataLoader, Dataset
import torch

import fastmri # We will also use fastmri library
from fastmri.data import subsample, transforms # use for generating undersampling mask, transforming tensors

# %%
# This is how you can make a custom dataset class

class MRIDataset(Dataset):
    def __init__(self, root, center_fractions=[0.06,0.06,0.06], accelerations=[4,5,6]):
        self.examples = []
        Files = list(pathlib.Path(root).glob('*.h5'))
        for fname in Files:
            h5file = h5py.File(fname, 'r')
            kspace = h5file['kspace']
            nsl = kspace.shape[0] # get number of slices
            self.examples += [(fname, sl) for sl in range(nsl)]
        
        self.mask_func = subsample.EquispacedMaskFunc(center_fractions=center_fractions, accelerations=accelerations)
    def __len__(self):
        return len(self.examples)
    def __getitem__(self, idx):
        fname, sl = self.examples[idx]
        with h5py.File(fname, 'r') as hr:
            kspace, sens = hr['kspace'][sl], hr['sens'][sl]
        kspace = kspace / 10 # divide by 10 because the values are too large
        im_coil = sp.ifft(kspace, axes=[1, 2])
        im_true = np.sum(im_coil * np.conj(sens), axis=0) # im_true is the fully sampled reconned image
        
        mask = self.mask_func(list(im_true.shape) + [1])[...,0]                              
        mask = np.expand_dims(mask, axis=0)
        masked_kspace = kspace * mask # undersampled kspace
        mask = np.expand_dims(mask, axis=-1)
        
        # Now transform everything to tensor. The complex kspace will be changed to [real, imag] in the final axis
        masked_kspace = transforms.to_tensor(masked_kspace) 
        mask = transforms.to_tensor(mask)
        sens = transforms.to_tensor(sens)
        im_true = np.expand_dims(im_true, axis=0)
        im_true = transforms.to_tensor(im_true)
                        
        return masked_kspace, mask.byte(), sens, im_true

# %%
# Then you can use the dataloader like this

basefolder = '/mnt/dense/kanghyun/summer_dset/div_coronal_pd/Test'
dset = MRIDataset(basefolder)

# %%
# You can see what's in the dset by looking insider dset.examples

print('Total Slices:',len(dset))
print(dset.examples) # first is path to h5file and second is the slice number
# Out:
# Total Slices: 149
# [(PosixPath('/mnt/dense/kanghyun/summer_dset/div_coronal_pd/Test/rawdata_4.h5'), 0), (PosixPath('/mnt/dense/kanghyun/summer_dset/div_coronal_pd/Test/rawdata_4.h5'), 1), (PosixPath('/mnt/dense/kanghyun/summer_dset/div_coronal_pd/Test/rawdata_4.h5'), 2), (PosixPath('/mnt/dense/kanghyun/summer_dset/div_coronal_pd/Test/rawdata_4.h5'), 3), (PosixPath('/mnt/dense/kanghyun/summer_dset/div_coronal_pd/Test/rawdata_4.h5'), 4), (PosixPath('/mnt/dense/kanghyun/summer_dset/div_coronal_pd/Test/rawdata_4.h5'), 5), (PosixPath('/mnt/dense/kanghyun/summer_dset/div_coronal_pd/Test/rawdata_4.h5'), 6), (PosixPath('/mnt/dense/kanghyun/summer_dset/div_coronal_pd/Test/rawdata_4.h5'), 7), (PosixPath('/mnt/dense/kanghyun/summer_dset/div_coronal_pd/Test/rawdata_4.h5'), 8), (PosixPath('/mnt/dense/kanghyun/summer_dset/div_coronal_pd/Test/rawdata_4.h5'), 9), (PosixPath('/mnt/dense/kanghyun/summer_dset/div_coronal_pd/Test/rawdata_4.h5'), 10), (PosixPath('/mnt/dense/kanghyun/summer_dset/div_coronal_pd/Test/rawdata_4.h5'), 11), (PosixPath('/mnt/dense/kanghyun/summer_dset/div_coronal_pd/Test/rawdata_4.h5'), 12), (PosixPath('/mnt/dense/kanghyun/summer_dset/div_coronal_pd/Test/rawdata_4.h5'), 13), (PosixPath('/mnt/dense/kanghyun/summer_dset/div_coronal_pd/Test/rawdata_4.h5'), 14), (PosixPath('/mnt/dense/kanghyun/summer_dset/div_coronal_pd/Test/rawdata_4.h5'), 15), (PosixPath('/mnt/dense/kanghyun/summer_dset/div_coronal_pd/Test/rawdata_4.h5'), 16), (PosixPath('/mnt/dense/kanghyun/summer_dset/div_coronal_pd/Test/rawdata_4.h5'), 17), (PosixPath('/mnt/dense/kanghyun/summer_dset/div_coronal_pd/Test/rawdata_4.h5'), 18), (PosixPath('/mnt/dense/kanghyun/summer_dset/div_coronal_pd/Test/rawdata_4.h5'), 19), (PosixPath('/mnt/dense/kanghyun/summer_dset/div_coronal_pd/Test/rawdata_4.h5'), 20), (PosixPath('/mnt/dense/kanghyun/summer_dset/div_coronal_pd/Test/rawdata_4.h5'), 21), (PosixPath('/mnt/dense/kanghyun/summer_dset/div_coronal_pd/Test/rawdata_4.h5'), 22), (PosixPath('/mnt/dense/kanghyun/summer_dset/div_coronal_pd/Test/rawdata_4.h5'), 23), (PosixPath('/mnt/dense/kanghyun/summer_dset/div_coronal_pd/Test/rawdata_4.h5'), 24), (PosixPath('/mnt/dense/kanghyun/summer_dset/div_coronal_pd/Test/rawdata_4.h5'), 25), (PosixPath('/mnt/dense/kanghyun/summer_dset/div_coronal_pd/Test/rawdata_4.h5'), 26), (PosixPath('/mnt/dense/kanghyun/summer_dset/div_coronal_pd/Test/rawdata_4.h5'), 27), (PosixPath('/mnt/dense/kanghyun/summer_dset/div_coronal_pd/Test/rawdata_4.h5'), 28), (PosixPath('/mnt/dense/kanghyun/summer_dset/div_coronal_pd/Test/rawdata_4.h5'), 29), (PosixPath('/mnt/dense/kanghyun/summer_dset/div_coronal_pd/Test/rawdata_4.h5'), 30), (PosixPath('/mnt/dense/kanghyun/summer_dset/div_coronal_pd/Test/rawdata_4.h5'), 31), (PosixPath('/mnt/dense/kanghyun/summer_dset/div_coronal_pd/Test/rawdata_4.h5'), 32), (PosixPath('/mnt/dense/kanghyun/summer_dset/div_coronal_pd/Test/rawdata_4.h5'), 33), (PosixPath('/mnt/dense/kanghyun/summer_dset/div_coronal_pd/Test/rawdata_4.h5'), 34), (PosixPath('/mnt/dense/kanghyun/summer_dset/div_coronal_pd/Test/rawdata_4.h5'), 35), (PosixPath('/mnt/dense/kanghyun/summer_dset/div_coronal_pd/Test/rawdata_6.h5'), 0), (PosixPath('/mnt/dense/kanghyun/summer_dset/div_coronal_pd/Test/rawdata_6.h5'), 1), (PosixPath('/mnt/dense/kanghyun/summer_dset/div_coronal_pd/Test/rawdata_6.h5'), 2), (PosixPath('/mnt/dense/kanghyun/summer_dset/div_coronal_pd/Test/rawdata_6.h5'), 3), (PosixPath('/mnt/dense/kanghyun/summer_dset/div_coronal_pd/Test/rawdata_6.h5'), 4), (PosixPath('/mnt/dense/kanghyun/summer_dset/div_coronal_pd/Test/rawdata_6.h5'), 5), (PosixPath('/mnt/dense/kanghyun/summer_dset/div_coronal_pd/Test/rawdata_6.h5'), 6), (PosixPath('/mnt/dense/kanghyun/summer_dset/div_coronal_pd/Test/rawdata_6.h5'), 7), (PosixPath('/mnt/dense/kanghyun/summer_dset/div_coronal_pd/Test/rawdata_6.h5'), 8), (PosixPath('/mnt/dense/kanghyun/summer_dset/div_coronal_pd/Test/rawdata_6.h5'), 9), (PosixPath('/mnt/dense/kanghyun/summer_dset/div_coronal_pd/Test/rawdata_6.h5'), 10), (PosixPath('/mnt/dense/k ...

# %%
# and you can extract kspace, mask, sens, im_true by indexing
kspace, mask, sens, im_true = dset[20]
# this will take much faster if you copy the dataset to your home directory (SSD)

print(kspace.shape, mask.shape, sens.shape, im_true.shape)
# Notice that everything is in torch tensor
# Out:
# torch.Size([15, 577, 332, 2]) torch.Size([1, 1, 332, 1]) torch.Size([15, 577, 332, 2]) torch.Size([1, 577, 332, 2])

# %%
# Change the above variables to numpy again and plot them

kspace = transforms.tensor_to_complex_np(kspace)
sens = transforms.tensor_to_complex_np(sens)
im_true = transforms.tensor_to_complex_np(im_true)
print(kspace.shape, sens.shape, im_true.shape)
# Out:
# (15, 577, 332) (15, 577, 332) (1, 577, 332)

# %%
pl.ImagePlot(kspace**0.2,z=0) # this is undersampled kspace
pl.ImagePlot(sens,z=0) # this is sensitivity map
pl.ImagePlot(im_true) # this is true image

# %%
# Now let's make pytorch dataloader which can load the dataset automatically and do some useful things likes random shuffling

dloader = DataLoader(dset, batch_size=1, shuffle=True, num_workers=16)
# num_workers can stack 16 minibatch in parallel

# dloader is a generator and you can call it inside a for loop or use iterables

test_dloader = iter(dloader)
kspace, mask, sens, im_true = next(test_dloader) # notice that one more dimension is added
print(kspace.shape, mask.shape, sens.shape, im_true.shape)
# Out:
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 577, 332, 2])

# %%
# Change the above variables to numpy again and plot them

kspace = transforms.tensor_to_complex_np(kspace)
sens = transforms.tensor_to_complex_np(sens)
im_true = transforms.tensor_to_complex_np(im_true)
print(kspace.shape, sens.shape, im_true.shape)

pl.ImagePlot(kspace**0.2,z=1) # this is undersampled kspace
pl.ImagePlot(sens,z=1) # this is sensitivity map
pl.ImagePlot(im_true) # this is true image
# Out:
# (1, 15, 577, 332) (1, 15, 577, 332) (1, 1, 577, 332)

# %%
# now use them inside the for loop like this

for iidx, (kspace, mask, sens, im_true) in enumerate(dloader):
    print('{}th data'.format(iidx))
    print(kspace.shape, mask.shape, sens.shape)
# Out:
# 0th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 1th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 2th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 3th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 4th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 5th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 6th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 7th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 8th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 9th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 10th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 11th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 12th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 13th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 14th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 15th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 16th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 17th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 18th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 19th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 20th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 21th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 22th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 23th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 24th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 25th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 26th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 27th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 28th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 29th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 30th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 31th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 32th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 33th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 34th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 35th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 36th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 37th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 38th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 39th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 40th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 41th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 42th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 43th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 44th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 45th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 46th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 47th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 48th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 49th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 50th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 51th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 52th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 53th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 54th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 55th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 56th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 57th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 58th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 59th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 60th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 61th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 62th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 63th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 64th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 65th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 66th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 67th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 68th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 69th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 70th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 71th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 72th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 73th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 74th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 75th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 76th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 77th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 78th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 79th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 80th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 81th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 82th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 83th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 84th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 85th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 86th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 87th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 88th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 89th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 90th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 91th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 92th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 93th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 94th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 95th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 96th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 97th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 98th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 99th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 100th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 101th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 102th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 103th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 104th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 105th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 106th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 107th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 108th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 109th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 110th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 111th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 112th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 113th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 114th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 115th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 116th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 117th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 118th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 119th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 120th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 121th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 122th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 123th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 124th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 125th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 126th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 127th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 128th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 129th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 130th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 131th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 132th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 133th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 134th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 135th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 136th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 137th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 138th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 139th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 140th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 141th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 142th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 143th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 144th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 145th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 146th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 147th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])
# 148th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2])

# %%
# Now we will save this code in a separate dloader.py file for further usage
