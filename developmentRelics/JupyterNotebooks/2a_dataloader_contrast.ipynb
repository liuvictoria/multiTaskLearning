# %%
import numpy as np
import sigpy as sp
import os
import sigpy as sp
import matplotlib.pyplot as plt
import sigpy.plot as pl
import h5py
import pathlib  # pathlib is a good library for reading files in a nested folders

from torch.utils.data import DataLoader, Dataset
import torch

import fastmri  # We will also use fastmri library
# use for generating undersampling mask, transforming tensors
from fastmri.data import subsample, transforms

# This is how you can make a custom dataset class

class MRIDataset(Dataset):

    def __init__(
        self, roots, scarcities, seed=123,
        center_fractions=[0.06, 0.06, 0.06], accelerations=[6, 6, 6]
    ):
        self.rng = np.random.default_rng(seed)
        self.examples = []
        self.ratios = {}
        self.contrasts = {}
        for idx, root in enumerate(roots):
            # update contrast dict
            contrast = root.split('/')[-2]
            if contrast not in self.contrasts:
                self.contrasts[contrast] = len(self.contrasts)
                
            Files = list(pathlib.Path(root).glob('*.h5'))
            # subsample files
            Files = self.subset_sample(Files, scarcities[idx])
            self.ratios[contrast] = len(Files)

            # individual slices
            for fname in Files:
                h5file = h5py.File(fname, 'r')
                kspace = h5file['kspace']
                nsl = kspace.shape[0]  # get number of slices
                self.examples += [(fname, sl, contrast) for sl in range(nsl)]

        self.mask_func = subsample.EquispacedMaskFunc(
            center_fractions=center_fractions, accelerations=accelerations
        )

    def subset_sample(self, Files, scarcity):
        '''
        decrease number of Files by 1/2^{scarcity} in a reproducible manner
        '''
        for _ in range(scarcity):
            if int(len(Files) / 2) > 0:
                Files = self.rng.choice(Files, int(
                    len(Files) / 2), replace=False)
        return list(Files)

    def __len__(self):
        return len(self.examples)

    def __getitem__(self, idx):
        fname, sl, contrast = self.examples[idx]
        with h5py.File(fname, 'r') as hr:
            kspace, sens = hr['kspace'][sl], hr['sens'][sl]
        kspace = kspace / 10  # divide by 10 because the values are too large
        im_coil = sp.ifft(kspace, axes=[1, 2])
        im_true = np.sum(im_coil * np.conj(sens), axis=0)

        mask = self.mask_func(list(im_true.shape) + [1])[..., 0]
        mask = np.expand_dims(mask, axis=0)
        masked_kspace = kspace * mask  # undersampled kspace
        mask = np.expand_dims(mask, axis=-1)

        # Now transform everything to tensor.
        # The complex kspace will be changed to [real, imag] in the final axis
        masked_kspace = transforms.to_tensor(masked_kspace)
        mask = transforms.to_tensor(mask)
        sens = transforms.to_tensor(sens)
        im_true = np.expand_dims(im_true, axis=0)
        im_true = transforms.to_tensor(im_true)

        return masked_kspace, mask.byte(), sens, im_true, contrast


def genDataLoader(roots, scarcities, seed=123, shuffle=True):
    dset = MRIDataset(roots=roots, scarcities=scarcities, seed=seed)
    return (DataLoader(dset, batch_size=1, shuffle=shuffle, num_workers=16), dset.ratios)

# %%
# Then you can use the dataloader like this

basefolders = [
    '/mnt/dense/kanghyun/summer_dset/div_coronal_pd/Train', 
#     '/mnt/dense/kanghyun/summer_dset/div_coronal_pd_fs/Train'
]
dset = MRIDataset(basefolders, [0])

# %%
# You can see what's in the dset by looking insider dset.examples

print('Total Slices:',len(dset))
# print(dset.examples) # first is path to h5file and second is the slice number
print(dset.ratios)
# Out:
# Total Slices: 494
# {'div_coronal_pd': 13}

# %%
# and you can extract kspace, mask, sens, im_true by indexing
kspace, mask, sens, im_true, contrast = dset[20]
# this will take much faster if you copy the dataset to your home directory (SSD)

print(kspace.shape, mask.shape, sens.shape, im_true.shape)
# Notice that everything is in torch tensor
# Out:
# torch.Size([15, 577, 332, 2]) torch.Size([1, 1, 332, 1]) torch.Size([15, 577, 332, 2]) torch.Size([1, 577, 332, 2])

# %%
# Change the above variables to numpy again and plot them

kspace = transforms.tensor_to_complex_np(kspace)
sens = transforms.tensor_to_complex_np(sens)
im_true = transforms.tensor_to_complex_np(im_true)
print(kspace.shape, sens.shape, im_true.shape)
# Out:
# (15, 577, 332) (15, 577, 332) (1, 577, 332)

# %%
pl.ImagePlot(kspace**0.2,z=0) # this is undersampled kspace
pl.ImagePlot(sens,z=0) # this is sensitivity map
pl.ImagePlot(im_true) # this is true image

# %%
# Now let's make pytorch dataloader which can load the dataset automatically and do some useful things likes random shuffling

dloader = DataLoader(dset, batch_size=1, shuffle=True, num_workers=16)
# num_workers can stack 16 minibatch in parallel

# dloader is a generator and you can call it inside a for loop or use iterables

test_dloader = iter(dloader)
kspace, mask, sens, im_true, contrast = next(test_dloader) # notice that one more dimension is added
print(kspace.shape, mask.shape, sens.shape, im_true.shape)
# Out:
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 577, 332, 2])

# %%
# Change the above variables to numpy again and plot them

kspace = transforms.tensor_to_complex_np(kspace)
sens = transforms.tensor_to_complex_np(sens)
im_true = transforms.tensor_to_complex_np(im_true)
print(kspace.shape, sens.shape, im_true.shape)

pl.ImagePlot(kspace**0.2,z=1) # this is undersampled kspace
pl.ImagePlot(sens,z=1) # this is sensitivity map
pl.ImagePlot(im_true) # this is true image
# Out:
# (1, 15, 577, 332) (1, 15, 577, 332) (1, 1, 577, 332)

# %%
# now use them inside the for loop like this

for iidx, (kspace, mask, sens, im_true, contrast) in enumerate(dloader):
    print('{}th data'.format(iidx))
    print(kspace.shape, mask.shape, sens.shape, contrast)
# Out:
# 0th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 1th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 2th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 3th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 4th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 5th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 6th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 7th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 8th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 9th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 10th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 11th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 12th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 13th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 14th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 15th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 16th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 17th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 18th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 19th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 20th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 21th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 22th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 23th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 24th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 25th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 26th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 27th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 28th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 29th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 30th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 31th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 32th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 33th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 34th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 35th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 36th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 37th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 38th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 39th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 40th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 41th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 42th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 43th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 44th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 45th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 46th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 47th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 48th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 49th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 50th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 51th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 52th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 53th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 54th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 55th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 56th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 57th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 58th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 59th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 60th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 61th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 62th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 63th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 64th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 65th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 66th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 67th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 68th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 69th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 70th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 71th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 72th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 73th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 74th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 75th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 76th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 77th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 78th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 79th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 80th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 81th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 82th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 83th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 84th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 85th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 86th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 87th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 88th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 89th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 90th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 91th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 92th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 93th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 94th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 95th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 96th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 97th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 98th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 99th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 100th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 101th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 102th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 103th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 104th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 105th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 106th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 107th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 108th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 109th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 110th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 111th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 112th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 113th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 114th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 115th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 116th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 117th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 118th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 119th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 120th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 121th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 122th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 123th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 124th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 125th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 126th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 127th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 128th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 129th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 130th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 131th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 132th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 133th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 134th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 135th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 136th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 137th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 138th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 139th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 140th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 141th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 142th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 143th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 144th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 145th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 146th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 147th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 148th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 149th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 150th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 151th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 152th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 153th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 154th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 155th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 156th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 157th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 158th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 159th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 160th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 161th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 162th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 163th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 164th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 165th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 166th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 167th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 168th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 169th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 170th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 171th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 172th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 173th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 174th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 175th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 176th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 177th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 178th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 179th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 180th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 181th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 182th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 183th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 184th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 185th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 186th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 187th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 188th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 189th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 190th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 191th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 192th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 193th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 194th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 195th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 196th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 197th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 198th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 199th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 200th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 201th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 202th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 203th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 204th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 205th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 206th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 207th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 208th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 209th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 210th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 211th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 212th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 213th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 214th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 215th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 216th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 217th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 218th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 219th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 220th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 221th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 222th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 223th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 224th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 225th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 226th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 227th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 228th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 229th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 230th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 231th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 232th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 233th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 234th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 235th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 236th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 237th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 238th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 239th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 240th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 241th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 242th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 243th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 244th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 245th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 246th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 247th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 248th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 249th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 250th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 251th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 252th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 253th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 254th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 255th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 256th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 257th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 258th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 259th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 260th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 261th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 262th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 263th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 264th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 265th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 266th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 267th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 268th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 269th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 270th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# 271th data
# torch.Size([1, 15, 577, 332, 2]) torch.Size([1, 1, 1, 332, 1]) torch.Size([1, 15, 577, 332, 2]) ('div_coronal_pd',)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-6c5e0a2a0125> in <module>
#       1 # now use them inside the for loop like this
#       2
# ----> 3 for iidx, (kspace, mask, sens, im_true, contrast) in enumerate(dloader):
#       4     print('{}th data'.format(iidx))
#       5     print(kspace.shape, mask.shape, sens.shape, contrast)
#
# ~/miniconda3/envs/multiTask/lib/python3.8/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     519             if self._sampler_iter is None:
#     520                 self._reset()
# --> 521             data = self._next_data()
#     522             self._num_yielded += 1
#     523             if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~/miniconda3/envs/multiTask/lib/python3.8/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1184
#    1185             assert not self._shutdown and self._tasks_outstanding > 0
# -> 1186             idx, data = self._get_data()
#    1187             self._tasks_outstanding -= 1
#    1188             if self._dataset_kind == _DatasetKind.Iterable:
#
# ~/miniconda3/envs/multiTask/lib/python3.8/site-packages/torch/utils/data/dataloader.py in _get_data(self)
#    1150         else:
#    1151             while True:
# -> 1152                 success, data = self._try_get_data()
#    1153                 if success:
#    1154                     return data
#
# ~/miniconda3/envs/multiTask/lib/python3.8/site-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#     988         #   (bool: whether successfully get data, any: data if successful else None)
#     989         try:
# --> 990             data = self._data_queue.get(timeout=timeout)
#     991             return (True, data)
#     992         except Exception as e:
#
# ~/miniconda3/envs/multiTask/lib/python3.8/multiprocessing/queues.py in get(self, block, timeout)
#     105                 if block:
#     106                     timeout = deadline - time.monotonic()
# --> 107                     if not self._poll(timeout):
#     108                         raise Empty
#     109                 elif not self._poll():
#
# ~/miniconda3/envs/multiTask/lib/python3.8/multiprocessing/connection.py in poll(self, timeout)
#     255         self._check_closed()
#     256         self._check_readable()
# --> 257         return self._poll(timeout)
#     258
#     259     def __enter__(self):
#
# ~/miniconda3/envs/multiTask/lib/python3.8/multiprocessing/connection.py in _poll(self, timeout)
#     422
#     423     def _poll(self, timeout):
# --> 424         r = wait([self], timeout)
#     425         return bool(r)
#     426
#
# ~/miniconda3/envs/multiTask/lib/python3.8/multiprocessing/connection.py in wait(object_list, timeout)
#     929
#     930             while True:
# --> 931                 ready = selector.select(timeout)
#     932                 if ready:
#     933                     return [key.fileobj for (key, events) in ready]
#
# ~/miniconda3/envs/multiTask/lib/python3.8/selectors.py in select(self, timeout)
#     413         ready = []
#     414         try:
# --> 415             fd_event_list = self._selector.poll(timeout)
#     416         except InterruptedError:
#     417             return ready
#
# KeyboardInterrupt:

# %%
# Now we will save this code in a separate dloader.py file for further usage
